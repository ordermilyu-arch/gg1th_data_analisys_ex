# %% [markdown]
# # 와인분석 기본

# %%
import pandas as pd

# %% [markdown]
# ## [실습1] 데이터 프레임 만들기

# %%
# 데이터에 인덱스 포함되어 있는경우, 인덱스 컬럼 제외하고 로딩하기
data_path = 'datas/winemag-data_first150k.csv'
df = pd.read_csv(data_path).iloc[:,1:]
df.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   country      150925 non-null  str
#  1   description  150930 non-null  str
#  2   designation  105195 non-null  str
#  3   points       150930 non-null  int64
#  4   price        137235 non-null  float64
#  5   province     150925 non-null  str
#  6   region_1     125870 non-null  str
#  7   region_2     60953 non-null   str
#  8   variety      150930 non-null  str
#  9   winery       150930 non-null  str
# dtypes: float64(1), int64(1), str(8)
# memory usage: 11.5 MB

# %% [markdown]
# - 주요 컬럼 : country(와인 생산 국가), description(리뷰) points(점수), price(가격), province(지방)

# %%
# 리뷰의 디스크립션 컬럼을 desc로 지정
dsec = df[['country','description','points','price','province']]
dsec.head(15)
# Out:
#    country                                        description  points  price  \
# 0       US  This tremendous 100% varietal wine hails from ...      96  235.0
# 1    Spain  Ripe aromas of fig, blackberry and cassis are ...      96  110.0
# 2       US  Mac Watson honors the memory of a wine once ma...      96   90.0
# 3       US  This spent 20 months in 30% new French oak, an...      96   65.0
# 4   France  This is the top wine from La Bégude, named aft...      95   66.0
# 5    Spain  Deep, dense and pure from the opening bell, th...      95   73.0
# 6    Spain  Slightly gritty black-fruit aromas include a s...      95   65.0
# 7    Spain  Lush cedary black-fruit aromas are luxe and of...      95  110.0
# 8       US  This re-named vineyard was formerly bottled as...      95   65.0
# 9       US  The producer sources from two blocks of the vi...      95   60.0
# 10   Italy  Elegance, complexity and structure come togeth...      95   80.0
# 11      US  From 18-year-old vines, this supple well-balan...      95   48.0
# 12      US  A standout even in this terrific lineup of 201...      95   48.0
# 13  France  This wine is in peak condition. The tannins an...      95   90.0
# 14      US  With its sophisticated mix of mineral, acid an...      95  185.0
#
#               province
# 0           California
# 1       Northern Spain
# 2           California
# 3               Oregon
# 4             Provence
# 5       Northern Spain
# 6       Northern Spain
# 7       Northern Spain
# 8               Oregon
# 9           California
# 10  Northeastern Italy
# 11              Oregon
# 12              Oregon
# 13    Southwest France
# 14              Oregon

# %% [markdown]
# ## [실습2] data access

# %% [markdown]
# - description 컬럼의 첫번째 데이터를, first_description 이라는 변수에 저장하기

# %%
# 방법1
first_description = df[['description']]
first_description.head()
# Out:
#                                          description
# 0  This tremendous 100% varietal wine hails from ...
# 1  Ripe aromas of fig, blackberry and cassis are ...
# 2  Mac Watson honors the memory of a wine once ma...
# 3  This spent 20 months in 30% new French oak, an...
# 4  This is the top wine from La Bégude, named aft...

# %% [markdown]
# - description column의 값들 중, 첫번재부터 10번째 데이터까지를 first_description 변수에 저장한다.

# %%
# loc() 방식
first_description = first_description.head(10)
first_description
# Out:
#                                          description
# 0  This tremendous 100% varietal wine hails from ...
# 1  Ripe aromas of fig, blackberry and cassis are ...
# 2  Mac Watson honors the memory of a wine once ma...
# 3  This spent 20 months in 30% new French oak, an...
# 4  This is the top wine from La Bégude, named aft...
# 5  Deep, dense and pure from the opening bell, th...
# 6  Slightly gritty black-fruit aromas include a s...
# 7  Lush cedary black-fruit aromas are luxe and of...
# 8  This re-named vineyard was formerly bottled as...
# 9  The producer sources from two blocks of the vi...

# %%
# iloc() 방식
first_description = first_description.iloc[:10]
first_description
# Out:
#                                          description
# 0  This tremendous 100% varietal wine hails from ...
# 1  Ripe aromas of fig, blackberry and cassis are ...
# 2  Mac Watson honors the memory of a wine once ma...
# 3  This spent 20 months in 30% new French oak, an...
# 4  This is the top wine from La Bégude, named aft...
# 5  Deep, dense and pure from the opening bell, th...
# 6  Slightly gritty black-fruit aromas include a s...
# 7  Lush cedary black-fruit aromas are luxe and of...
# 8  This re-named vineyard was formerly bottled as...
# 9  The producer sources from two blocks of the vi...

# %% [markdown]
# - 인덱스가 1,2,3,4,5,8 인 데이터를, sample_reviews 변수에 저장한다.

# %%
sample_reviews = 
sample_reviews
# Out:
#   Cell In[99], line 1
#     sample_reviews =
#                      ^
# SyntaxError: invalid syntax

# %%
# 인덱스가 0, 1, 10, 100인 데이터에서, 컬럼이 country, province, region_1, region_2인 데이터만 가져오기
# Out:
#     country            province     region_1     region_2
# 0        US          California  Napa Valley         Napa
# 1     Spain      Northern Spain         Toro          NaN
# 10    Italy  Northeastern Italy       Collio          NaN
# 100      US          California  South Coast  South Coast

# %% [markdown]
# ## [실습3] 데이터 필터링
# - Italy 에서 만들어진 와인만 가져오기

# %%
# nan 값 포함해서 유니크한 값 가져옴
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %%
# Out:
# 49

# %%
# unique한 값의 갯수, nan은 제외한 갯수 계산
# Out:
# 48

# %%
df.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925     True
# 150926    False
# 150927     True
# 150928    False
# 150929     True
# Name: country, Length: 150930, dtype: bool

# %%
# - Italy 에서 만들어진 와인만 가져오세요
# df.loc[행,열]

# %% [markdown]
# - 리뷰점수가 95점 이상이고, Australia 또는 New Zealand 에서 만들어진 와인 데이터를 가져오세요

# %%
# 리뷰점수가 95점 이상이고, Australia 또는 New Zealand 에서 만들어진 와인 데이터를 가져오세요
# df.loc[행, 열]
