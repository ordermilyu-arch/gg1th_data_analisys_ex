# %%
import os
import pandas as pd

# 1. data 폴더 생성
os.makedirs('data', exist_ok=True)

# 2. 예시 인구 데이터 생성
population_data = {
    '지역': ['서울', '부산', '대구', '인천'],
    '인구수': [9400000, 3300000, 2300000, 3000000]
}

df = pd.DataFrame(population_data)

# 3. CSV 파일로 저장
df.to_csv('data/population.csv', index=False, encoding='cp949')

# 4. 다시 CSV 파일 읽기
df = pd.read_csv('data/population.csv', encoding='cp949')

df.head()
# Out:
#    지역      인구수
# 0  서울  9400000
# 1  부산  3300000
# 2  대구  2300000
# 3  인천  3000000

# %%
import pandas as pd

df = pd.read_csv('population.csv', encoding='cp949')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('population.csv', encoding='cp949')
#       4
#       5 df.head()
#
# File ~/data_analisys_ex/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...
